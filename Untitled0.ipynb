# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[3])

# %%
X_train = X_train/255
X_test = X_test/255

# %%
y_train = y_train/255

# %%
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=25,validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 1.2293e-09 - accuracy: 0.0985 - val_loss: 3.0796e-10 - val_accuracy: 0.0995
# Epoch 2/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 1.1673e-10 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 3/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 2.4835e-12 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 4/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 5/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 6/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 7/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 8/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 9/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 10/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 11/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 12/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 13/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 14/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 15/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 16/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 17/25
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 18/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 19/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 20/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 21/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 22/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 23/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 24/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995
# Epoch 25/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0985 - val_loss: 0.0000e+00 - val_accuracy: 0.0995

# %%
y_prob = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_prob.argmax(axis=1)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pred=y_prob.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.098

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_accuracy'])

# %%
plt.imshow(X_test[1])

# %%
model.predict(X_test[1].reshape(1,28,28)).argmax(axis=1)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([0])
